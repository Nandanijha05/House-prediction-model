# %%
import pandas as pd

# %%
df = pd.read_csv("../data/train.csv")

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df["LotFrontage" ]
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
missing=df.isnull().sum

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
miss=df.isnull().mean().sort_index(ascending=True)

# %%
miss[miss>0]
# Out:
# Alley           0.937671
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# BsmtQual        0.025342
# Electrical      0.000685
# Fence           0.807534
# FireplaceQu     0.472603
# GarageCond      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageType      0.055479
# GarageYrBlt     0.055479
# LotFrontage     0.177397
# MasVnrArea      0.005479
# MasVnrType      0.597260
# MiscFeature     0.963014
# PoolQC          0.995205
# dtype: float64

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
print(num_cols)
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
miss=df[num_cols].isnull().sum()
miss[miss>0]
# Out:
# LotFrontage    259
# MasVnrArea       8
# GarageYrBlt     81
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
df['LotFrontage'].plot(kind='kde', ax=ax, color='blue')

# variable imputed with the mean
# X_train['LotFrontageplot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
mean_value=df["LotFrontage"].mean()

# %%
df_arbitrary = df.copy()

# %%
df_arbitrary["LotFrontage"].describe()
# Out:
# count    1460.000000
# mean       70.049958
# std        22.024023
# min        21.000000
# 25%        60.000000
# 50%        70.049958
# 75%        79.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
df_arbitrary["LotFrontage"] = df_arbitrary["LotFrontage"].fillna(mean_value)

# %%
df["LotFrontage"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_arbitrary["LotFrontage"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_arbitrary["LotFrontage"].value_counts().sort_index().head()
# Out:
# LotFrontage
# 21.0    23
# 24.0    19
# 30.0     6
# 32.0     5
# 33.0     1
# Name: count, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
df['LotFrontage'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
df_arbitrary['LotFrontage'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
df["LotFrontage"] = df["LotFrontage"].fillna(mean_value)1
# Out:
#   Cell In[96], line 1
#     df["LotFrontage"] = df["LotFrontage"].fillna(mean_value)1
#                                                             ^
# SyntaxError: invalid syntax

# %%
from sklearn.impute import SimpleImputer

# %%
mean_imputer = SimpleImputer(strategy="mean")

# %%
df["LotFrontage"] = mean_imputer.fit_transform(
    df[["LotFrontage"]]l
)
# Out:
#   Cell In[97], line 2
#     df[["LotFrontage"]]l
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('Original LotFrontage variable variance: ', df['LotFrontage'].var())
# Out:
# Original LotFrontage variable variance:  485.05757539267887

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
df['LotFrontage'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
# X_train['LotFrontageplot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
