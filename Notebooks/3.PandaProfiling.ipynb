# %%
import pandas as pd


df = pd.read_csv("../data/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
# %pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ydata_profiling import ProfileReport
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
profile=ProfileReport(title="House Price Dataset Report")
profile.to_notebook_iframe()
profile.to_file("house_price_report.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 profile=ProfileReport(title="House Price Dataset Report")
#       2 profile.to_notebook_iframe()
#       3 profile.to_file("house_price_report.html")
#
# NameError: name 'ProfileReport' is not defined

# %%
# Out:
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_12240\3661833351.py", line 4, in <module>
#     from ydata_profiling import ProfileReport
#   File "C:\Users\user\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\__init__.py", line 11, in <module>
#     from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\compare_reports.py", line 12, in <module>
#     from ydata_profiling.profile_report import ProfileReport
#   File "C:\Users\user\AppData\Roaming\Python\Python313\site-packages\ydata_profiling\profile_report.py", line 11, in <module>
#     import pkg_resources
# ModuleNotFoundError: No module named 'pkg_resources'
